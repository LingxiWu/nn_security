# %%
from pandas import * # file io
import math
from matplotlib import pyplot as plt

def Sort_Tuple(tup): 
    tup.sort(key = lambda x: x[1], reverse=True) 
    return tup 

############################# 
######### 0u ##############
data_0u = read_csv("1R_FS_0u_FFT.csv")

freq_0u = data_0u["FFT_analysis X"]
real_0u = data_0u["FFT_analysis YRe"]
img_0u = data_0u["FFT_analysis YReImag"]

# mag
mag_0u = []
for i in range(0, len(freq_0u)):
    mag_0u.append(math.sqrt(real_0u[i]**2 + img_0u[i]**2))

# a list of tuples ([freq_0, mag_0], [freq_1, mag_1], ...,)
tup_list_0u = []
for i in range(0, 5):
    print(freq_0u[i])
    print(mag_0u[i])
    tup_0u = (freq_0u[i], mag_0u[i])
    tup_list_0u.append(tup_0u)

print(tup_list[0])

Sort_Tuple(tup_list_0u)
print(tup_list[:3])
# Out:
# 0.0
# 3.060335587641532e-06
# 200000.0
# 2.069045019409023e-09
# 399999.99999999994
# 1.0345410540014074e-09
# 599999.9999999999
# 6.896807259998436e-10
# 799999.9999999999
# 5.172676526292018e-10
# (2757800000.0, 1.287966307391035e-10)
# [(2757800000.0, 1.287966307391035e-10), (4872199999.999999, 1.6812333633235623e-10), (4009200000.0, 1.9536478273280956e-10)]

# %%
# ############################# 
# ######### 2u ##############
# data_2u = read_csv("1R_FS_2u_FFT.csv")

# freq_2u = data_2u["FFT_analysis X"]
# real_2u = data_2u["FFT_analysis YRe"]
# img_2u = data_2u["FFT_analysis YReImag"]

# # mag
# mag_2u = []
# for i in range(0, len(freq_2u)):
#     mag_2u.append(math.sqrt(real_2u[i]**2 + img_2u[i]**2))

# # a list of tuples ([freq_0, mag_0], [freq_1, mag_1], ...,)
# tup_list_2u = []
# for i in range(0, len(freq_2u)):
#     tup_2u = (freq_2u[i], mag_2u[i])
#     tup_list_2u.append(tup_2u)

# print(Sort_Tuple(tup_list_2u[:20]))

# ############################# 
# ######### 4u ##############
# data_4u = read_csv("1R_FS_4u_FFT.csv")

# freq_4u = data_4u["FFT_analysis X"]
# real_4u = data_4u["FFT_analysis YRe"]
# img_4u = data_4u["FFT_analysis YReImag"]

# # mag
# mag_4u = []
# for i in range(0, len(freq_4u)):
#     mag_4u.append(math.sqrt(real_4u[i]**2 + img_4u[i]**2))

# # a list of tuples ([freq_0, mag_0], [freq_1, mag_1], ...,)
# tup_list_4u = []
# for i in range(0, len(freq_4u)):
#     tup_4u = (freq_4u[i], mag_4u[i])
#     tup_list_4u.append(tup_4u)

# print(Sort_Tuple(tup_list_4u[:20]))

# ############################# 
# ######### 8p5u ##############
# data_8p5u = read_csv("1R_FS_8p5u_FFT.csv")

# freq_8p5u = data_8p5u["FFT_analysis X"]
# real_8p5u = data_8p5u["FFT_analysis YRe"]
# img_8p5u = data_8p5u["FFT_analysis YReImag"]

# # mag
# mag_8p5u = []
# for i in range(0, len(freq_8p5u)):
#     mag_8p5u.append(math.sqrt(real_8p5u[i]**2 + img_8p5u[i]**2))

# # a list of tuples ([freq_0, mag_0], [freq_1, mag_1], ...,)
# tup_list_8p5u = []
# for i in range(0, len(freq_8p5u)):
#     tup_8p5u = (freq_8p5u[i], mag_8p5u[i])
#     tup_list_8p5u.append(tup_8p5u)

# print(Sort_Tuple(tup_list_8p5u[:20]))
