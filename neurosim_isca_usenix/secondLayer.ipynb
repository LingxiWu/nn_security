# %%
import csv
import numpy as np

conductances = [] # 400 * 100

file = open("cond_1.csv")
csvreader = csv.reader(file)

conductances = [] # 400 rows
for row in csvreader:
    conductances.append(row)

file.close()

# transpose array. 1st list are conds of 1st SL, 2nd list are conds of 2nd SL
row_major = np.array(conductances)
col_major = row_major.transpose()
# Out:
# ['8.1666666666666685912e-07' '2.4500000000000002597e-06'
#  '4.0833333333333337662e-06' '2.5265625000000004266e-06'
#  '1.7656250000000000359e-07' '2.6031250000000005936e-06'
#  '5.000000000000000409e-06' '1.7864583333333336286e-06'
#  '4.0625000000000002794e-07' '5.000000000000000409e-06'
#  '4.2364583333333341001e-06' '1.0463541666666668305e-06'
#  '3.4197916666666673468e-06' '3.5729166666666676807e-06'
#  '1.9395833333333337507e-06' '4.0625000000000002794e-07'
#  '5.000000000000000409e-06' '3.4197916666666673468e-06'
#  '2.5265625000000004266e-06' '4.0833333333333337662e-06'
#  '4.9000000000000005194e-06' '4.9000000000000005194e-06'
#  '9.9999999999999995475e-08' '5.000000000000000409e-06'
#  '4.8281250000000008899e-07' '3.6494791666666678476e-06'
#  '4.0625000000000002794e-07' '3.6494791666666678476e-06'
#  '5.5937500000000004417e-07' '4.313020833333334267e-06'
#  '3.4963541666666675138e-06' '5.000000000000000409e-06'
#  '5.000000000000000409e-06' '2.8328125000000010944e-06'
# ...
